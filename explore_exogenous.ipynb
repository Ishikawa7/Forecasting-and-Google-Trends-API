# %%
import pandas as pd
import numpy as np
import math

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
sns.set()

# %%
# read df_exogenous
df_exogenous = pd.read_csv('df_exogenous.csv', index_col=0)
df_exogenous.set_index('date', inplace=True)
df_exogenous
# Out:
#               Vacanze     Viaggi      Gita  Google Maps   Traffico  \
# date
# 2021-06-01   6.125000   3.708333  3.500000     4.458333   2.000000
# 2021-06-02   7.458333   5.660714  5.309524     3.386905   5.000000
# 2021-06-03   7.296171   7.753378  3.229730     3.922297   3.576577
# 2021-06-04   6.883095   6.715952  3.252381     4.179286   3.975238
# 2021-06-05   6.716549   5.798389  2.486769     4.803404   2.972685
# ...               ...        ...       ...          ...        ...
# 2022-11-27   2.456444   2.702952  1.177987    10.633998   0.917924
# 2022-11-28   1.842333   2.568880  0.883490    10.121332   0.688443
# 2022-11-29  12.861750  18.706660  4.037618    20.320999   6.026749
# 2022-11-30  20.990062  30.759162  6.517796    28.667832  13.738812
# 2022-12-01  22.742547  42.319371  4.888347    29.500874  16.054109
#
#             Traffico Milano       Mare   Montagna  Lago Garda  Santo Ambrogio  \
# date
# ...

# %%
# examine correlations
px.imshow(df_exogenous.corr(method='spearman'), 
    labels=dict(x='Exogenous Variables', y='Exogenous Variables', color='Correlation'),
    color_continuous_scale='RdBu_r',
    aspect="auto")
